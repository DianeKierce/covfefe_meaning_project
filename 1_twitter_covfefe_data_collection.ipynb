# %% [markdown]
# # Capstone Project
# Diane Kierce
# General Assembly
# DSI Seattle 02
#
#
# ### #covfefe: Finding Meaning in Usage
#
# #### Data Source:
# On June 13-14, 2017 I used twitterscraper (https://github.com/taspinar/twitterscraper) to download all available tweets that matched the search term "covfefe" through Twitter's search function. The initial data set contained 531,980 tweets. EDA on that data set indicated that the text of the tweets was so messy as to not be useful, so I changed tactics and focused instead on the hashtags. (See Appendix A for the EDA on the tweet text.)
#
# Since twitterscraper does not scrape the hashtags separately from the text and does not scrape information about the user's number of followers or the number of favorites and retweets for each tweet, I then used Twitter's API to mine the available tweets with the hashtag "#covfefe." The main tradeoff with this approach was that I was limited to the available time period of nine days whereas with twitterscraper I was able to go back to the first usage of "covfefe" on May 31, 2017. Using the API on June 17, I was able to mine 59,345 tweets returned by Twitter's search function for the search term "#covfefe" dated from June 8, 2017 through June 16, 2017.
#
# #### In this notebook:
# This notebook contains the code I used to mine the #covfefe tweets using the Twitter API with the Python Twitter wrapper.

# %%
import twitter, datetime
import pandas as pd
import time

# Diane's keys:
twitter_keys = {
    'consumer_key':        'redacted',
    'consumer_secret':     'redacted',
    'access_token_key':    'redacted',
    'access_token_secret': 'redacted'
}


# initializing the API

api = twitter.Api(consumer_key = twitter_keys['consumer_key'],
                  consumer_secret = twitter_keys['consumer_secret'],
                  access_token_key = twitter_keys['access_token_key'],
                  access_token_secret = twitter_keys['access_token_secret'],
                  sleep_on_rate_limit=True)
        # sleep_on_rate_limit=True pauses the requests to avoid going over the rate limit (per 15 minute window)

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
class TweetMiner(object):

    result_limit    =   20    
    api             =   False
    data            =   []
    
    # Maximum result_limit is 100
    def __init__(self, keys_dict, api, result_limit = 20):
        
        self.api = api
        self.twitter_keys = keys_dict
        
        self.result_limit = result_limit
        
# defining a function to mine search data

    # Maximum for max_pages is 180 per 15 minute window when using the App API
    def mine_search_term(self, term=None, raw_query=None, mine_retweets=False, include_entities=True, max_pages=5):

        data           =  []
        last_tweet_id  =  False
        page           =  1
        
        while page <= max_pages:
            
            if last_tweet_id:
                statuses   =   self.api.GetSearch(term=term, raw_query=raw_query, count=self.result_limit, 
                                                  max_id=last_tweet_id - 1, include_entities=include_entities)        
            else:
                statuses   =   self.api.GetSearch(term=term, raw_query=raw_query, count=self.result_limit,
                                                  include_entities=include_entities)
                
            for item in statuses:

                mined = {
                    'tweet_id':              item.id,
                    'user_screen_name':      item.user.screen_name,
                    'user_handle':           item.user.name,
                    'user_id':               item.user.id,
                    'user_location':         item.user.location,
                    'user_followers_count':  item.user.followers_count,
                    'user_friends_count':    item.user.friends_count,
                    'user_lang':             item.user.lang,
                    'retweet_count':         item.retweet_count,
                    'text':                  item.text,
                    'mined_at':              datetime.datetime.now(),
                    'created_at':            item.created_at,
                    'media':                 item.media,
                    'hashtags':              item.hashtags,
                    'urls':                  item.urls,
                    'favorite_count':        item.favorite_count,
                    'posting_method':        item.source,
                    
                }
                
                last_tweet_id = item.id
                data.append(mined)
                
            page += 1
            
        return data

# %%
# instantiating a TweetMiner
# max number of results per request is 500

miner = TweetMiner(twitter_keys, api, result_limit=500)

miner

# %%
tweets01 = miner.mine_search_term(term='#covfefe since:2017-05-30 until:2017-06-17', 
                                  raw_query=None, mine_retweets=False, max_pages=1000, 
                                  include_entities=True)

# %%
df = pd.DataFrame(tweets01)

df.head()
# Out:
#                        created_at  favorite_count  \
# 0  Fri Jun 16 13:13:32 +0000 2017            1336
# 1  Fri Jun 16 16:53:35 +0000 2017             389
# 2  Fri Jun 16 16:25:06 +0000 2017             497
# 3  Fri Jun 16 23:59:46 +0000 2017               0
# 4  Fri Jun 16 23:59:17 +0000 2017               0
#
#                                             hashtags  \
# 0  [{"text": "trump"}, {"text": "maga"}, {"text":...
# 1           [{"text": "covfefe"}, {"text": "trump"}]
# 2  [{"text": "AmericaFirst"}, {"text": "covfefe"}...
# 3  [{"text": "AmericaFirst"}, {"text": "covfefe"}...
# 4  [{"text": "CNNisISIS"}, {"text": "AlBaghdadi"}...
#
#                                                media  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  [{"display_url": "pic.twitter.com/U5Wg4g1Ird",...
#
#                     mined_at  \
# 0 2017-06-17 22:45:08.039302
# 1 2017-06-17 22:45:08.039313
# 2 2017-06-17 22:45:08.039318
# 3 2017-06-17 22:45:08.039322
# 4 2017-06-17 22:45:08.039326
#
#                                       posting_method  retweet_count  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...            899
# 1  <a href="http://twitter.com" rel="nofollow">Tw...            271
# 2  <a href="http://twitter.com" rel="nofollow">Tw...            281
# 3  <a href="http://twitter.com/download/iphone" r...            281
# 4  <a href="http://twitter.com/download/iphone" r...              4
#
#                                                 text            tweet_id  \
# 0  AMERICA AGREES! Gohmert: There Is No Collusion...  875702885572595712
# 1  JUST FIRE MUELLER! Deputy AG Just Dropped Warn...  875758262959960068
# 2  #AmericaFirst - Obama's Anchor Baby Program (D...  875751095414521858
# 3  RT @WayneDupreeShow: #AmericaFirst - Obama's A...  875865514626646016
# 4  RT @politstrip: 'Caliphate News Network' mourn...  875865396045389825
#
#                                                 urls  user_followers_count  \
# 0  [{"expanded_url": "http://waynedupree.com/gohm...                192275
# 1  [{"expanded_url": "http://waynedupree.com/depu...                192275
# 2  [{"expanded_url": "http://waynedupree.com/trum...                192275
# 3  [{"expanded_url": "http://waynedupree.com/trum...                  3268
# 4                                                 []                   110
#
#    user_friends_count       user_handle     user_id user_lang  \
# 0                9517    🎙Wayne Dupree   282695161        en
# 1                9517    🎙Wayne Dupree   282695161        en
# 2                9517    🎙Wayne Dupree   282695161        en
# 3                4999      Crystal kemp  2481854702        en
# 4                  85  Elizabeth Wright  3707893403        en
#
#                   user_location user_screen_name
# 0  USAF Desert Storm/Shield Vet  WayneDupreeShow
# 1  USAF Desert Storm/Shield Vet  WayneDupreeShow
# 2  USAF Desert Storm/Shield Vet  WayneDupreeShow
# 3             Pennsylvania, USA     ckemp1542400
# 4                                 ErwrightWright

# %%
df.shape
# Out:
# (59345, 17)

# %%
# Saving to .csv so that I can work with this data set without having to re-mine the tweets
df.to_csv('covfefe_hashtag_api_tweets.csv', sep=',', encoding='utf-8')

# %%
tweets01
# Out:
# [{'created_at': u'Fri Jun 16 13:13:32 +0000 2017',
#   'favorite_count': 1336,
#   'hashtags': [Hashtag(Text=u'trump'),
#    Hashtag(Text=u'maga'),
#    Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39302),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 899,
#   'text': u'AMERICA AGREES! Gohmert: There Is No Collusion With Trump And Russia; Drop Special Counsel https://t.co/Z6UaT3cVHm #trump #maga #covfefe',
#   'tweet_id': 875702885572595712,
#   'urls': [URL(URL=https://t.co/Z6UaT3cVHm, ExpandedURL=http://waynedupree.com/gohmert-drop-special-counsel/)],
#   'user_followers_count': 192275,
#   'user_friends_count': 9517,
#   'user_handle': u'\U0001f399Wayne Dupree',
#   'user_id': 282695161,
#   'user_lang': u'en',
#   'user_location': u'USAF Desert Storm/Shield Vet',
#   'user_screen_name': u'WayneDupreeShow'},
#  {'created_at': u'Fri Jun 16 16:53:35 +0000 2017',
#   'favorite_count': 389,
#   'hashtags': [Hashtag(Text=u'covfefe'), Hashtag(Text=u'trump')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39313),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 271,
#   'text': u'JUST FIRE MUELLER! Deputy AG Just Dropped Warning To Americans About "Anonymous Allegations" https://t.co/0JxqSmSkSZ #covfefe #trump',
#   'tweet_id': 875758262959960068,
#   'urls': [URL(URL=https://t.co/0JxqSmSkSZ, ExpandedURL=http://waynedupree.com/deputy-ag-drops-confusing-press-release/)],
#   'user_followers_count': 192275,
#   'user_friends_count': 9517,
#   'user_handle': u'\U0001f399Wayne Dupree',
#   'user_id': 282695161,
#   'user_lang': u'en',
#   'user_location': u'USAF Desert Storm/Shield Vet',
#   'user_screen_name': u'WayneDupreeShow'},
#  {'created_at': u'Fri Jun 16 16:25:06 +0000 2017',
#   'favorite_count': 497,
#   'hashtags': [Hashtag(Text=u'AmericaFirst'),
#    Hashtag(Text=u'covfefe'),
#    Hashtag(Text=u'trump')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39318),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 281,
#   'text': u"#AmericaFirst - Obama's Anchor Baby Program (DAPA) Was Just Rescinded By Trump https://t.co/B8imehOAHw #covfefe #trump",
#   'tweet_id': 875751095414521858,
#   'urls': [URL(URL=https://t.co/B8imehOAHw, ExpandedURL=http://waynedupree.com/trump-rescinds-anchor-baby-program/)],
#   'user_followers_count': 192275,
#   'user_friends_count': 9517,
#   'user_handle': u'\U0001f399Wayne Dupree',
#   'user_id': 282695161,
#   'user_lang': u'en',
#   'user_location': u'USAF Desert Storm/Shield Vet',
#   'user_screen_name': u'WayneDupreeShow'},
#  {'created_at': u'Fri Jun 16 23:59:46 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'AmericaFirst'),
#    Hashtag(Text=u'covfefe'),
#    Hashtag(Text=u'trump')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39322),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 281,
#   'text': u"RT @WayneDupreeShow: #AmericaFirst - Obama's Anchor Baby Program (DAPA) Was Just Rescinded By Trump https://t.co/B8imehOAHw #covfefe #trump",
#   'tweet_id': 875865514626646016,
#   'urls': [URL(URL=https://t.co/B8imehOAHw, ExpandedURL=http://waynedupree.com/trump-rescinds-anchor-baby-program/)],
#   'user_followers_count': 3268,
#   'user_friends_count': 4999,
#   'user_handle': u'Crystal kemp',
#   'user_id': 2481854702,
#   'user_lang': u'en',
#   'user_location': u'Pennsylvania, USA',
#   'user_screen_name': u'ckemp1542400'},
#  {'created_at': u'Fri Jun 16 23:59:17 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'CNNisISIS'),
#    Hashtag(Text=u'AlBaghdadi'),
#    Hashtag(Text=u'Covfefe'),
#    Hashtag(Text=u'MAGA')],
#   'media': [Media(ID=875864440142417922, Type=photo, DisplayURL='pic.twitter.com/U5Wg4g1Ird')],
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39326),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 4,
#   'text': u"RT @politstrip: 'Caliphate News Network' mourns the loss of their leader \U0001f62d #CNNisISIS #AlBaghdadi #Covfefe #MAGA https://t.co/U5Wg4g1Ird",
#   'tweet_id': 875865396045389825,
#   'urls': [],
#   'user_followers_count': 110,
#   'user_friends_count': 85,
#   'user_handle': u'Elizabeth Wright',
#   'user_id': 3707893403,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'ErwrightWright'},
#  {'created_at': u'Fri Jun 16 23:59:12 +0000 2017',
#   'favorite_count': 1,
#   'hashtags': [Hashtag(Text=u'COVFEFE'), Hashtag(Text=u'ISLAND')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39330),
#   'posting_method': u'<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'retweet_count': 0,
#   'text': u'\U0001f3a5 #COVFEFE #ISLAND DAY ONE! @ Corral Beach https://t.co/GDpZG8aMgo',
#   'tweet_id': 875865374897586176,
#   'urls': [URL(URL=https://t.co/GDpZG8aMgo, ExpandedURL=https://www.instagram.com/p/BVa3UiBhcGt/)],
#   'user_followers_count': 70948,
#   'user_friends_count': 1793,
#   'user_handle': u'DAVE',
#   'user_id': 33977973,
#   'user_lang': u'en',
#   'user_location': u'los angeles, ca',
#   'user_screen_name': u'Youngbeardo'},
#  {'created_at': u'Fri Jun 16 23:59:12 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39333),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875865374532804608,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 84,
#   'user_friends_count': 156,
#   'user_handle': u'Teresa Mulligan',
#   'user_id': 728699618339520512,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'TeresaMulligan7'},
#  {'created_at': u'Fri Jun 16 23:59:09 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'areyoukidding'),
#    Hashtag(Text=u'smh'),
#    Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39336),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 0,
#   'text': u'Lucky us to have such a distinguished leader. #areyoukidding #smh #covfefe https://t.co/YkaBnRl7u4',
#   'tweet_id': 875865361865859073,
#   'urls': [URL(URL=https://t.co/YkaBnRl7u4, ExpandedURL=https://twitter.com/realdonaldtrump/status/875690204564258816)],
#   'user_followers_count': 319,
#   'user_friends_count': 211,
#   'user_handle': u'Carrie Blankenship',
#   'user_id': 38244909,
#   'user_lang': u'en',
#   'user_location': u'Lake Stevens, WA',
#   'user_screen_name': u'kidsinthecity'},
#  {'created_at': u'Fri Jun 16 23:58:32 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39340),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 4310,
#   'text': u"RT @billmaher: The very last thing I want to hear from this @WhiteHouse is 'His fingers just pressed the wrong button.' #Covfefe https://t.\u2026",
#   'tweet_id': 875865205439377408,
#   'urls': [],
#   'user_followers_count': 986,
#   'user_friends_count': 26,
#   'user_handle': u'FELIX SARCONA',
#   'user_id': 829824667749859328,
#   'user_lang': u'en',
#   'user_location': u'New York, NY',
#   'user_screen_name': u'Sarcona_Felix'},
#  {'created_at': u'Fri Jun 16 23:58:24 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39344),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875865173281701888,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 2957,
#   'user_friends_count': 2152,
#   'user_handle': u'Elena Maria Vidal',
#   'user_id': 16672909,
#   'user_lang': u'en',
#   'user_location': u'Easton, Maryland',
#   'user_screen_name': u'emvidal'},
#  {'created_at': u'Fri Jun 16 23:57:30 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39347),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875864945023307776,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 797,
#   'user_friends_count': 57,
#   'user_handle': u'Margosun',
#   'user_id': 573053124,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'MargosunC'},
#  {'created_at': u'Fri Jun 16 23:57:18 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'SteveScaliseShooting'),
#    Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39351),
#   'posting_method': u'<a href="https://periscope.tv" rel="nofollow">Periscope</a>',
#   'retweet_count': 897,
#   'text': u'RT @WayneDupreeShow: My quick take  #SteveScaliseShooting #covfefe https://t.co/TNnAA4gsVK',
#   'tweet_id': 875864895983542272,
#   'urls': [URL(URL=https://t.co/TNnAA4gsVK, ExpandedURL=https://www.pscp.tv/w/bBBgOTUwMzY4MDB8MXlvS01CalhhUFJHUfcfXST1SIxNZST8wfFaIx2HPkyHDflVtp51QDRhmIqu)],
#   'user_followers_count': 3654,
#   'user_friends_count': 2092,
#   'user_handle': u'MichelleMercedes\xae\U0001f4ac',
#   'user_id': 762649892191932416,
#   'user_lang': u'en',
#   'user_location': u'\U0001f1fa\U0001f1f8',
#   'user_screen_name': u'ihartchelle'},
#  {'created_at': u'Fri Jun 16 23:57:16 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39354),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875864887028850690,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 1712,
#   'user_friends_count': 284,
#   'user_handle': u'Deplorable Mark',
#   'user_id': 895625785,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'markhplant'},
#  {'created_at': u'Fri Jun 16 23:57:16 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39357),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 0,
#   'text': u'Despite the negative press #covfefe',
#   'tweet_id': 875864886500356098,
#   'urls': [],
#   'user_followers_count': 266,
#   'user_friends_count': 371,
#   'user_handle': u'$uicide $hadow',
#   'user_id': 724675850336088065,
#   'user_lang': u'en',
#   'user_location': u'Pittsburgh, PA',
#   'user_screen_name': u'Pyxis412'},
#  {'created_at': u'Fri Jun 16 23:57:03 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe'),
#    Hashtag(Text=u'POTUS'),
#    Hashtag(Text=u'MAGA')],
#   'media': [Media(ID=875864829260648450, Type=photo, DisplayURL='pic.twitter.com/pilyMkbyP2')],
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39360),
#   'posting_method': u'<a href="https://www.automatedstench.com" rel="nofollow">Drumpf Bot v7</a>',
#   'retweet_count': 0,
#   'text': u'Oi @realDonaldTrump do you really believe that 1.5m people attended your inauguration? #Covfefe #POTUS #MAGA https://t.co/pilyMkbyP2',
#   'tweet_id': 875864831068450817,
#   'urls': [],
#   'user_followers_count': 73,
#   'user_friends_count': 4,
#   'user_handle': u'Drumpf Bot',
#   'user_id': 817784219564994562,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'automatedstench'},
#  {'created_at': u'Fri Jun 16 23:56:47 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'AmericaFirst'),
#    Hashtag(Text=u'covfefe'),
#    Hashtag(Text=u'trump')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39363),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 281,
#   'text': u"RT @WayneDupreeShow: #AmericaFirst - Obama's Anchor Baby Program (DAPA) Was Just Rescinded By Trump https://t.co/B8imehOAHw #covfefe #trump",
#   'tweet_id': 875864765222060035,
#   'urls': [URL(URL=https://t.co/B8imehOAHw, ExpandedURL=http://waynedupree.com/trump-rescinds-anchor-baby-program/)],
#   'user_followers_count': 587,
#   'user_friends_count': 130,
#   'user_handle': u'Manuel Skippy',
#   'user_id': 781947890289827840,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'SkippyManuel'},
#  {'created_at': u'Fri Jun 16 23:56:13 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'WhoWasObama'),
#    Hashtag(Text=u'covfefe'),
#    Hashtag(Text=u'trump')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39366),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 173,
#   'text': u'RT @WayneDupreeShow: EXTRA WINNING! Trump Cancels Obama Completely One-Sided Cuba Deal! https://t.co/OYa5bnGo7H #WhoWasObama #covfefe #trump',
#   'tweet_id': 875864621034467330,
#   'urls': [URL(URL=https://t.co/OYa5bnGo7H, ExpandedURL=http://waynedupree.com/trump-cancels-obama-cuba-deal/)],
#   'user_followers_count': 587,
#   'user_friends_count': 130,
#   'user_handle': u'Manuel Skippy',
#   'user_id': 781947890289827840,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'SkippyManuel'},
#  {'created_at': u'Fri Jun 16 23:56:07 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39370),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875864597982568448,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 587,
#   'user_friends_count': 130,
#   'user_handle': u'Manuel Skippy',
#   'user_id': 781947890289827840,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'SkippyManuel'},
#  {'created_at': u'Fri Jun 16 23:56:01 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'alternativefacts'),
#    Hashtag(Text=u'Covfefe'),
#    Hashtag(Text=u'covfefeyourself'),
#    Hashtag(Text=u'FakeNews')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39373),
#   'posting_method': u'<a href="https://www.google.com" rel="nofollow">alternativefacts</a>',
#   'retweet_count': 1,
#   'text': u'RT @TaggartRehnn: @Unpersuaded112 PHENOMENAL!!! #alternativefacts #Covfefe #covfefeyourself #FakeNews',
#   'tweet_id': 875864573030670336,
#   'urls': [],
#   'user_followers_count': 1989,
#   'user_friends_count': 3,
#   'user_handle': u'Alternative facts',
#   'user_id': 823803346884640768,
#   'user_lang': u'en',
#   'user_location': u'Washington, DC',
#   'user_screen_name': u'AlternatFacts'},
#  {'created_at': u'Fri Jun 16 23:55:51 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39376),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875864530659749888,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 770,
#   'user_friends_count': 195,
#   'user_handle': u'Grace Kelly',
#   'user_id': 602375668,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'realgrace_kelly'},
#  {'created_at': u'Fri Jun 16 23:55:32 +0000 2017',
#   'favorite_count': 2,
#   'hashtags': [Hashtag(Text=u'CNNisISIS'),
#    Hashtag(Text=u'AlBaghdadi'),
#    Hashtag(Text=u'Covfefe'),
#    Hashtag(Text=u'MAGA')],
#   'media': [Media(ID=875864440142417922, Type=photo, DisplayURL='pic.twitter.com/U5Wg4g1Ird')],
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39382),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 4,
#   'text': u"'Caliphate News Network' mourns the loss of their leader \U0001f62d #CNNisISIS #AlBaghdadi #Covfefe #MAGA https://t.co/U5Wg4g1Ird",
#   'tweet_id': 875864450389037056,
#   'urls': [],
#   'user_followers_count': 5138,
#   'user_friends_count': 5494,
#   'user_handle': u'Politically Stripped',
#   'user_id': 1143762104,
#   'user_lang': u'en',
#   'user_location': u'U.S.A.',
#   'user_screen_name': u'politstrip'},
#  {'created_at': u'Fri Jun 16 23:55:30 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39386),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875864443791568896,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 368,
#   'user_friends_count': 628,
#   'user_handle': u'ItalianMother4Trump',
#   'user_id': 811491725365706753,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'LoveThyTrump'},
#  {'created_at': u'Fri Jun 16 23:55:17 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39389),
#   'posting_method': u'<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#   'retweet_count': 1,
#   'text': u"RT @SpanishRose5272: @BombayFred Where there's smoke...\U0001f525\U0001f525\U0001f525\n#Covfefe",
#   'tweet_id': 875864388434972672,
#   'urls': [],
#   'user_followers_count': 2075,
#   'user_friends_count': 2017,
#   'user_handle': u'BombayBeachArtifacts',
#   'user_id': 780568218393948160,
#   'user_lang': u'en',
#   'user_location': u'Bombay Beach, California',
#   'user_screen_name': u'BombayFred'},
#  {'created_at': u'Fri Jun 16 23:55:06 +0000 2017',
#   'favorite_count': 1,
#   'hashtags': [Hashtag(Text=u'alternativefacts'),
#    Hashtag(Text=u'Covfefe'),
#    Hashtag(Text=u'covfefeyourself'),
#    Hashtag(Text=u'FakeNews')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39392),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 1,
#   'text': u'@Unpersuaded112 PHENOMENAL!!! #alternativefacts #Covfefe #covfefeyourself #FakeNews',
#   'tweet_id': 875864341840629765,
#   'urls': [],
#   'user_followers_count': 200,
#   'user_friends_count': 250,
#   'user_handle': u'Taggart Rehnn',
#   'user_id': 862324808939339777,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'TaggartRehnn'},
#  {'created_at': u'Fri Jun 16 23:54:58 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39395),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 0,
#   'text': u'@realDonaldTrump I follow you for your humor. #covfefe',
#   'tweet_id': 875864307933659137,
#   'urls': [],
#   'user_followers_count': 222,
#   'user_friends_count': 118,
#   'user_handle': u'\U0001f380MzTrap\U0001f525Daddy\U0001f3da',
#   'user_id': 38980417,
#   'user_lang': u'en',
#   'user_location': u'Phuket, Thailand',
#   'user_screen_name': u'JadaRhymes'},
#  {'created_at': u'Fri Jun 16 23:54:44 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39398),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875864250371022849,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 344,
#   'user_friends_count': 645,
#   'user_handle': u'Win Rideout',
#   'user_id': 824470268479279104,
#   'user_lang': u'en',
#   'user_location': u'Tucson, AZ',
#   'user_screen_name': u'rideout_win'},
#  {'created_at': u'Fri Jun 16 23:54:16 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39401),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875864133845086208,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 638,
#   'user_friends_count': 823,
#   'user_handle': u'Kim',
#   'user_id': 758810880758861824,
#   'user_lang': u'en',
#   'user_location': u'Hollywood, FL',
#   'user_screen_name': u'klehmann63'},
#  {'created_at': u'Fri Jun 16 23:54:01 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39404),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875864070896746497,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 431,
#   'user_friends_count': 642,
#   'user_handle': u'Rudy',
#   'user_id': 3327152563,
#   'user_lang': u'en',
#   'user_location': u'California, USA',
#   'user_screen_name': u'funatanytime2'},
#  {'created_at': u'Fri Jun 16 23:53:48 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39407),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875864014101860352,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 1604,
#   'user_friends_count': 1970,
#   'user_handle': u'cmconcepts',
#   'user_id': 15598131,
#   'user_lang': u'en',
#   'user_location': u'JOIN TEAMDUNN Here',
#   'user_screen_name': u'cmconcepts'},
#  {'created_at': u'Fri Jun 16 23:53:39 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39410),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 529,
#   'text': u'RT @WayneDupreeShow: FAKE!! CNN Takes Part In UK Muslims Staging Anti-ISIS Rally, Includes Little Children https://t.co/ZH95uQWI6N #Covfefe\u2026',
#   'tweet_id': 875863975207895040,
#   'urls': [URL(URL=https://t.co/ZH95uQWI6N, ExpandedURL=http://waynedupree.com/cnn-takes-part-in-fake-muslims-staging-anti-isis-rally/)],
#   'user_followers_count': 10826,
#   'user_friends_count': 10575,
#   'user_handle': u'Skye Shepard',
#   'user_id': 456775778,
#   'user_lang': u'en',
#   'user_location': u'Not Lost In A Lost World- IN',
#   'user_screen_name': u'SkyeShepard'},
#  {'created_at': u'Fri Jun 16 23:53:14 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'covfefe')],
#   'media': [Media(ID=869926309291450368, Type=video, DisplayURL='pic.twitter.com/yVeg17qtol')],
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39413),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 1724,
#   'text': u'RT @kwilli1046: Loretta Lynch calling for marching, blood, death in the streets   \nto oppose Pres Trump\n#covfefe https://t.co/yVeg17qtol',
#   'tweet_id': 875863873567375361,
#   'urls': [],
#   'user_followers_count': 111,
#   'user_friends_count': 22,
#   'user_handle': u'Nicholas Swett',
#   'user_id': 814729065542258688,
#   'user_lang': u'en',
#   'user_location': u'Mill Creek, WA',
#   'user_screen_name': u'swettnj7227'},
#  {'created_at': u'Fri Jun 16 23:52:46 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39416),
#   'posting_method': u'<a href="http://fivenineteenfoto.com" rel="nofollow">Collect Call 1 (JiJi App)</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875863752838656000,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 3089,
#   'user_friends_count': 2326,
#   'user_handle': u'Collect Call',
#   'user_id': 4775810719,
#   'user_lang': u'en',
#   'user_location': u'Hollywood and Right Behind You. ',
#   'user_screen_name': u'collectcall1'},
#  {'created_at': u'Fri Jun 16 23:52:38 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'CovFefe'), Hashtag(Text=u'GOP')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39419),
#   'posting_method': u'<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#   'retweet_count': 1,
#   'text': u'RT @HillHrc2016: "Very powerful" witch magic tweets for @realDonaldTrump and his secret #CovFefe coven of #GOP witches and warlocks #WitchH\u2026',
#   'tweet_id': 875863720014098432,
#   'urls': [],
#   'user_followers_count': 682,
#   'user_friends_count': 1201,
#   'user_handle': u'10Ashus',
#   'user_id': 707911472123351040,
#   'user_lang': u'en',
#   'user_location': u'USA',
#   'user_screen_name': u'HillHrc2016'},
#  {'created_at': u'Fri Jun 16 23:52:38 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'CNN'),
#    Hashtag(Text=u'FoxNews'),
#    Hashtag(Text=u'Rueters'),
#    Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39422),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 0,
#   'text': u'I solved it. "Covfefe" was meant 2b "cacophony". It\'s the only definition that makes sense from context. #CNN #FoxNews #Rueters #Covfefe',
#   'tweet_id': 875863719737208832,
#   'urls': [],
#   'user_followers_count': 0,
#   'user_friends_count': 0,
#   'user_handle': u'Joseph Vaux',
#   'user_id': 874425757530980352,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'JosephVaux'},
#  {'created_at': u'Fri Jun 16 23:52:36 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39425),
#   'posting_method': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'retweet_count': 2,
#   'text': u'RT @kuhb00m: I hope everyone that had @APRcoffee #Covfefe enjoyed it! I see those beans making an appearance again later this year',
#   'tweet_id': 875863711478624257,
#   'urls': [],
#   'user_followers_count': 598,
#   'user_friends_count': 1012,
#   'user_handle': u'TT-reTweets',
#   'user_id': 1608948967,
#   'user_lang': u'en',
#   'user_location': u'Minneapolis',
#   'user_screen_name': u'TTongco'},
#  {'created_at': u'Fri Jun 16 23:52:33 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39427),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 0,
#   'text': u'#Covfefe',
#   'tweet_id': 875863699633958913,
#   'urls': [],
#   'user_followers_count': 417,
#   'user_friends_count': 953,
#   'user_handle': u'Quayon Nelson',
#   'user_id': 242884936,
#   'user_lang': u'en',
#   'user_location': u'Jersey Stand Up',
#   'user_screen_name': u'QuietStorm58'},
#  {'created_at': u'Fri Jun 16 23:52:22 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39431),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875863653354012674,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 852,
#   'user_friends_count': 178,
#   'user_handle': u'Laurie Ann R Baker',
#   'user_id': 54935632,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'LaurieAnnBaker'},
#  {'created_at': u'Fri Jun 16 23:52:21 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'EditTweets'), Hashtag(Text=u'covfefe')],
#   'media': [Media(ID=875381627249098752, Type=animated_gif, DisplayURL='pic.twitter.com/vvkdMBVNp6')],
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39434),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 1271,
#   'text': u"RT @vitalii: @MKBHD I suggest Retweet if you'd want this to happen before we walk on Mars! #EditTweets #covfefe https://t.co/vvkdMBVNp6",
#   'tweet_id': 875863650095050752,
#   'urls': [],
#   'user_followers_count': 28,
#   'user_friends_count': 104,
#   'user_handle': u'Absoulute Trash',
#   'user_id': 748250350902181892,
#   'user_lang': u'en',
#   'user_location': u'Florida, USA',
#   'user_screen_name': u'mikayla_s_c'},
#  {'created_at': u'Fri Jun 16 23:51:15 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'CovFefe'), Hashtag(Text=u'tcot')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39437),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 0,
#   'text': u'In the end we win.... .@iamwill #CovFefe #tcot https://t.co/g4vseF9C4e',
#   'tweet_id': 875863371823828993,
#   'urls': [URL(URL=https://t.co/g4vseF9C4e, ExpandedURL=https://twitter.com/meyday1/status/875861323627741184)],
#   'user_followers_count': 1186,
#   'user_friends_count': 1479,
#   'user_handle': u'Mark Young Infidel',
#   'user_id': 54458811,
#   'user_lang': u'en',
#   'user_location': u'Left Coast, but not for long!!',
#   'user_screen_name': u'meyday1'},
#  {'created_at': u'Fri Jun 16 23:51:13 +0000 2017',
#   'favorite_count': 9,
#   'hashtags': [Hashtag(Text=u'CovFefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39440),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 1,
#   'text': u'\u0627\u0645\u0634\u0628\u0645 \u06a9\u0633\u06cc \u0645\u0627\u0631\u0648 \u062f\u0648\u0633\u062a \u0646\u062f\u0627\u0634\u062a...\n\n#CovFefe',
#   'tweet_id': 875863366522343424,
#   'urls': [],
#   'user_followers_count': 989,
#   'user_friends_count': 1143,
#   'user_handle': u'\u070d \u06af\u0640\u2588\u0640\u0648\u0645\u0648\u0644 \u0628\u0632\u0631\u06af \u070d',
#   'user_id': 54499483,
#   'user_lang': u'en',
#   'user_location': u'Tehran',
#   'user_screen_name': u'G00M0L'},
#  {'created_at': u'Fri Jun 16 23:50:48 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39443),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 1,
#   'text': u'RT @berblanc2: H\xe9 ho, monsieur le ministre @RichardFerrand, tous vos montages financiers c\u2019est un peu #covfefe, non ?',
#   'tweet_id': 875863257998905345,
#   'urls': [],
#   'user_followers_count': 406,
#   'user_friends_count': 829,
#   'user_handle': u'ClairObscur',
#   'user_id': 2560932945,
#   'user_lang': u'fr',
#   'user_location': u'Ailleurs.',
#   'user_screen_name': u'Clair_Obscur2'},
#  {'created_at': u'Fri Jun 16 23:50:39 +0000 2017',
#   'favorite_count': 1,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39446),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 1,
#   'text': u"@BombayFred Where there's smoke...\U0001f525\U0001f525\U0001f525\n#Covfefe",
#   'tweet_id': 875863221168513024,
#   'urls': [],
#   'user_followers_count': 1350,
#   'user_friends_count': 1878,
#   'user_handle': u'Rebel Rebel \u2744\u270a\U0001f1fa\U0001f1f8',
#   'user_id': 1056081252,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'SpanishRose5272'},
#  {'created_at': u'Fri Jun 16 23:50:03 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'MAGA'),
#    Hashtag(Text=u'Trump'),
#    Hashtag(Text=u'Covfefe')],
#   'media': [Media(ID=875863066755436545, Type=photo, DisplayURL='pic.twitter.com/xnQkwsqae4')],
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39448),
#   'posting_method': u'<a href="https://www.automatedstench.com" rel="nofollow">Confused Tucker 2</a>',
#   'retweet_count': 0,
#   'text': u'Hey @TuckerCarlson @FoxNews please try to at least pretend you know what you are doing #MAGA #Trump #Covfefe https://t.co/xnQkwsqae4',
#   'tweet_id': 875863069951488006,
#   'urls': [],
#   'user_followers_count': 15,
#   'user_friends_count': 1,
#   'user_handle': u'Confused Tucker',
#   'user_id': 844965092315811840,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'ConfusedTucker'},
#  {'created_at': u'Fri Jun 16 23:49:57 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'grammarrules'),
#    Hashtag(Text=u'gradingtrump'),
#    Hashtag(Text=u'covfefe')],
#   'media': [Media(ID=875863032294854656, Type=photo, DisplayURL='pic.twitter.com/ikCUo3L7wc')],
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39451),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 0,
#   'text': u'Wrong use of so, incomplete sentences, incorrect capitalizations, hyperbole...\n\n#grammarrules #gradingtrump #covfefe https://t.co/ikCUo3L7wc',
#   'tweet_id': 875863047247720449,
#   'urls': [],
#   'user_followers_count': 13,
#   'user_friends_count': 179,
#   'user_handle': u'Emma Berkowitz',
#   'user_id': 871539206195212288,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'emma_berkowitz'},
#  {'created_at': u'Fri Jun 16 23:49:50 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39454),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 2,
#   'text': u'RT @Truth_Opotomous: Great story of courage!\n#Covfefe V https://t.co/7RyzhYzcmn',
#   'tweet_id': 875863014527741953,
#   'urls': [URL(URL=https://t.co/7RyzhYzcmn, ExpandedURL=https://twitter.com/newtgingrich/status/875781156121260032)],
#   'user_followers_count': 4122,
#   'user_friends_count': 3002,
#   'user_handle': u'DesireTheRight',
#   'user_id': 429801709,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'Welsh58'},
#  {'created_at': u'Fri Jun 16 23:49:31 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39458),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875862935318532096,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 312,
#   'user_friends_count': 110,
#   'user_handle': u'Maisie B',
#   'user_id': 823436826727895044,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'24hrTVMazi'},
#  {'created_at': u'Fri Jun 16 23:49:07 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39461),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875862834407776259,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 1499,
#   'user_friends_count': 1677,
#   'user_handle': u'rottiefreek',
#   'user_id': 48467882,
#   'user_lang': u'en',
#   'user_location': u'Pa.',
#   'user_screen_name': u'rottiefreek'},
#  {'created_at': u'Fri Jun 16 23:48:50 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'ImSorryToBotherYou'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39464),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 0,
#   'text': u'#ImSorryToBotherYou but have you seen any #covfefe?',
#   'tweet_id': 875862765822464000,
#   'urls': [],
#   'user_followers_count': 5894,
#   'user_friends_count': 4602,
#   'user_handle': u'Gia',
#   'user_id': 3372256589,
#   'user_lang': u'en',
#   'user_location': u'USA',
#   'user_screen_name': u'Joyannah73'},
#  {'created_at': u'Fri Jun 16 23:48:23 +0000 2017',
#   'favorite_count': 7,
#   'hashtags': [Hashtag(Text=u'comey'),
#    Hashtag(Text=u'MuellerLeaks'),
#    Hashtag(Text=u'trumprussia')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39467),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 1,
#   'text': u"@realDonaldTrump It's a disgrace!! I'll swing by so we can chat about #comey , #MuellerLeaks &amp; #trumprussia over a\u2026 https://t.co/9EKK79bXFv",
#   'tweet_id': 875862652446285825,
#   'urls': [URL(URL=https://t.co/9EKK79bXFv, ExpandedURL=https://twitter.com/i/web/status/875862652446285825)],
#   'user_followers_count': 429,
#   'user_friends_count': 1025,
#   'user_handle': u'TheRoc',
#   'user_id': 378076054,
#   'user_lang': u'en',
#   'user_location': u'New York, NY',
#   'user_screen_name': u'SROC7770'},
#  {'created_at': u'Fri Jun 16 23:48:09 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'WhoWasObama'),
#    Hashtag(Text=u'covfefe'),
#    Hashtag(Text=u'trump')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39470),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 173,
#   'text': u'RT @WayneDupreeShow: EXTRA WINNING! Trump Cancels Obama Completely One-Sided Cuba Deal! https://t.co/OYa5bnGo7H #WhoWasObama #covfefe #trump',
#   'tweet_id': 875862593377890305,
#   'urls': [URL(URL=https://t.co/OYa5bnGo7H, ExpandedURL=http://waynedupree.com/trump-cancels-obama-cuba-deal/)],
#   'user_followers_count': 878,
#   'user_friends_count': 975,
#   'user_handle': u'alan shepard',
#   'user_id': 37457651,
#   'user_lang': u'en',
#   'user_location': u'austin,tx',
#   'user_screen_name': u'mechanic45'},
#  {'created_at': u'Fri Jun 16 23:47:28 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39473),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875862421239341056,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 1203,
#   'user_friends_count': 680,
#   'user_handle': u'Scott Torok',
#   'user_id': 787616685263958016,
#   'user_lang': u'en',
#   'user_location': u'Balboa Heights, Tucson',
#   'user_screen_name': u'scottt1984'},
#  {'created_at': u'Fri Jun 16 23:47:03 +0000 2017',
#   'favorite_count': 1,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39476),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 0,
#   'text': u'Cant even wrap my head around this one, Crazy!\n#Covfefe https://t.co/s135BkudCt',
#   'tweet_id': 875862317581422592,
#   'urls': [URL(URL=https://t.co/s135BkudCt, ExpandedURL=https://twitter.com/RealJamesWoods/status/875820189685764096)],
#   'user_followers_count': 2260,
#   'user_friends_count': 4577,
#   'user_handle': u'PVT Server Covfefe',
#   'user_id': 763911555817742336,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'Truth_Opotomous'},
#  {'created_at': u'Fri Jun 16 23:47:01 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'AmericaFirst'),
#    Hashtag(Text=u'covfefe'),
#    Hashtag(Text=u'trump')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39479),
#   'posting_method': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'retweet_count': 281,
#   'text': u"RT @WayneDupreeShow: #AmericaFirst - Obama's Anchor Baby Program (DAPA) Was Just Rescinded By Trump https://t.co/B8imehOAHw #covfefe #trump",
#   'tweet_id': 875862307204550656,
#   'urls': [URL(URL=https://t.co/B8imehOAHw, ExpandedURL=http://waynedupree.com/trump-rescinds-anchor-baby-program/)],
#   'user_followers_count': 502,
#   'user_friends_count': 845,
#   'user_handle': u'Giraffe & Turtle',
#   'user_id': 124825351,
#   'user_lang': u'en',
#   'user_location': u'USA',
#   'user_screen_name': u'artvos'},
#  {'created_at': u'Fri Jun 16 23:46:54 +0000 2017',
#   'favorite_count': 2,
#   'hashtags': [Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39482),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 1,
#   'text': u'How many spins would a fidget spinner spin if a fidget could spin spins #covfefe',
#   'tweet_id': 875862277685227520,
#   'urls': [],
#   'user_followers_count': 135,
#   'user_friends_count': 113,
#   'user_handle': u'Jimmy Cuckboy',
#   'user_id': 201000032,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'Reednutz'},
#  {'created_at': u'Fri Jun 16 23:46:43 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'TrumpsArmy'), Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39485),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 206,
#   'text': u"RT @WayneDupreeShow: \U0001f633 VA Shooter's Kill List Of Republicans Was Found On Body After Death! https://t.co/KMRs7c60CP #TrumpsArmy #covfefe #T\u2026",
#   'tweet_id': 875862232449658882,
#   'urls': [URL(URL=https://t.co/KMRs7c60CP, ExpandedURL=http://waynedupree.com/va-shooter-kill-list-was-found-on-body/)],
#   'user_followers_count': 213,
#   'user_friends_count': 220,
#   'user_handle': u'Marla',
#   'user_id': 3004249311,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'marpas48'},
#  {'created_at': u'Fri Jun 16 23:46:41 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'WhoWasObama'),
#    Hashtag(Text=u'covfefe'),
#    Hashtag(Text=u'trump')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39488),
#   'posting_method': u'<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'retweet_count': 173,
#   'text': u'RT @WayneDupreeShow: EXTRA WINNING! Trump Cancels Obama Completely One-Sided Cuba Deal! https://t.co/OYa5bnGo7H #WhoWasObama #covfefe #trump',
#   'tweet_id': 875862223356280832,
#   'urls': [URL(URL=https://t.co/OYa5bnGo7H, ExpandedURL=http://waynedupree.com/trump-cancels-obama-cuba-deal/)],
#   'user_followers_count': 502,
#   'user_friends_count': 845,
#   'user_handle': u'Giraffe & Turtle',
#   'user_id': 124825351,
#   'user_lang': u'en',
#   'user_location': u'USA',
#   'user_screen_name': u'artvos'},
#  {'created_at': u'Fri Jun 16 23:45:59 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 8, 39491),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 1,
#   'text': u'RT @z_marks: yasss. Kenyans always ftw #Covfefe https://t.co/5h2u23O4jD',
#   'tweet_id': 875862047786971144,
#   'urls': [URL(URL=https://t.co/5h2u23O4jD, ExpandedURL=https://twitter.com/gchelwa/status/874178656913981440)],
#   'user_followers_count': 183,
#   'user_friends_count': 594,
#   'user_handle': u'Anna Miller',
#   'user_id': 2573343199,
#   'user_lang': u'en',
#   'user_location': u'Toronto',
#   'user_screen_name': u'MillerAnnaC'},
#  {'created_at': u'Fri Jun 16 23:45:32 +0000 2017',
#   'favorite_count': 1,
#   'hashtags': [Hashtag(Text=u'covfefe'),
#    Hashtag(Text=u'cheetohitler'),
# ...
#   'user_handle': u'Kosmo',
#   'user_id': 29269883,
#   'user_lang': u'en',
#   'user_location': u'Montreal, Quebec',
#   'user_screen_name': u'Omsok'},
#  {'created_at': u'Fri Jun 16 18:25:02 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'MAGA'),
#    Hashtag(Text=u'Trump'),
#    Hashtag(Text=u'Covfefe')],
#   'media': [Media(ID=875781275340210176, Type=photo, DisplayURL='pic.twitter.com/wPxS0Nd8mx')],
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724743),
#   'posting_method': u'<a href="https://www.automatedstench.com" rel="nofollow">Confused Tucker 2</a>',
#   'retweet_count': 0,
#   'text': u'Hello @TuckerCarlson @FoxNews A, B, C...then D, E, F... #MAGA #Trump #Covfefe https://t.co/wPxS0Nd8mx',
#   'tweet_id': 875781277827387392,
#   'urls': [],
#   'user_followers_count': 15,
#   'user_friends_count': 1,
#   'user_handle': u'Confused Tucker',
#   'user_id': 844965092315811840,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'ConfusedTucker'},
#  {'created_at': u'Fri Jun 16 18:24:53 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'covfefe'), Hashtag(Text=u'ParisAgreement')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724747),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 454,
#   'text': u"RT @RJSzczerba: @realDonaldTrump I heard #covfefe is a new flavor from Ben &amp; Jerry's. But it's mostly just nuts! #ParisAgreement #ParisAcco\u2026",
#   'tweet_id': 875781238841278464,
#   'urls': [],
#   'user_followers_count': 1338,
#   'user_friends_count': 2163,
#   'user_handle': u'texasrockette \U0001f1f2\U0001f1fd',
#   'user_id': 321761811,
#   'user_lang': u'en',
#   'user_location': u'The Waxler Asylum',
#   'user_screen_name': u'rb4s'},
#  {'created_at': u'Fri Jun 16 18:24:46 +0000 2017',
#   'favorite_count': 1,
#   'hashtags': [Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724750),
#   'posting_method': u'<a href="http://hedgeaccordingly.com" rel="nofollow">HApolitics</a>',
#   'retweet_count': 0,
#   'text': u'President Trump\u2019s \u2018negative press\u2019 #covfefe tweet turns Twitter heads $TWTR https://t.co/yznpzu1gBc',
#   'tweet_id': 875781212387856384,
#   'urls': [URL(URL=https://t.co/yznpzu1gBc, ExpandedURL=https://hedgeaccordingly.com/2017/05/president-trumps-negative-press-covfefe-tweet-turns-twitter-heads-twtr.html)],
#   'user_followers_count': 53126,
#   'user_friends_count': 25840,
#   'user_handle': u'Political HEDGE',
#   'user_id': 790019230389248000,
#   'user_lang': u'en',
#   'user_location': u'Beverly Hills, CA',
#   'user_screen_name': u'PoliticalHedge'},
#  {'created_at': u'Fri Jun 16 18:24:42 +0000 2017',
#   'favorite_count': 1,
#   'hashtags': [Hashtag(Text=u'Covfefe'), Hashtag(Text=u'TNG')],
#   'media': [Media(ID=875781186282561537, Type=photo, DisplayURL='pic.twitter.com/Ef8cyDZ6N4')],
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724753),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 0,
#   'text': u'#Covfefe \n#TNG https://t.co/Ef8cyDZ6N4',
#   'tweet_id': 875781195879120896,
#   'urls': [],
#   'user_followers_count': 348,
#   'user_friends_count': 1073,
#   'user_handle': u"It's Me Lori",
#   'user_id': 43944791,
#   'user_lang': u'en',
#   'user_location': u'South Carolina',
#   'user_screen_name': u'TheRealLori'},
#  {'created_at': u'Fri Jun 16 18:24:40 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724757),
#   'posting_method': u'<a href="https://favstar.fm" rel="nofollow">Favstar.FM</a>',
#   'retweet_count': 1,
#   'text': u"RT @JFMTheThird: It's no coincidence that, in pulling out of the Paris Accord, we saw an unprecedented spike in the US's #covfefe emissions.",
#   'tweet_id': 875781185930018816,
#   'urls': [],
#   'user_followers_count': 5462,
#   'user_friends_count': 1580,
#   'user_handle': u'danny',
#   'user_id': 3905131696,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'Mardigroan'},
#  {'created_at': u'Fri Jun 16 18:24:19 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'covfefe'),
#    Hashtag(Text=u'TheResistance'),
#    Hashtag(Text=u'2018midtermelections')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724761),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 0,
#   'text': u'#covfefe #TheResistance #2018midtermelections https://t.co/MO0pHkoNbk',
#   'tweet_id': 875781096683716609,
#   'urls': [URL(URL=https://t.co/MO0pHkoNbk, ExpandedURL=https://www.youtube.com/watch?v=ZRQHISbKrDY&feature=share)],
#   'user_followers_count': 18,
#   'user_friends_count': 46,
#   'user_handle': u'Nick LoGrasso',
#   'user_id': 872355665544699904,
#   'user_lang': u'en',
#   'user_location': u'Novato, CA',
#   'user_screen_name': u'NickLoGrasso1'},
#  {'created_at': u'Fri Jun 16 18:23:27 +0000 2017',
#   'favorite_count': 1,
#   'hashtags': [Hashtag(Text=u'covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724764),
#   'posting_method': u'<a href="http://www.twitter.com" rel="nofollow">Twitter for Windows</a>',
#   'retweet_count': 0,
#   'text': u'Love it! Limousine Liberals. Kind, yet telling term.i woke up, smelled the #covfefe \u2615\ufe0f last year when I boarded the\u2026 https://t.co/gPUEeHciAN',
#   'tweet_id': 875780881151033345,
#   'urls': [URL(URL=https://t.co/gPUEeHciAN, ExpandedURL=https://twitter.com/i/web/status/875780881151033345)],
#   'user_followers_count': 239,
#   'user_friends_count': 242,
#   'user_handle': u'Peggy Sous Chef',
#   'user_id': 4617828613,
#   'user_lang': u'en',
#   'user_location': u'Heartland IL, USA',
#   'user_screen_name': u'poozbestfriend'},
#  {'created_at': u'Fri Jun 16 18:23:18 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'LittleHavana'),
#    Hashtag(Text=u'BetterDealForCuba'),
#    Hashtag(Text=u'Covfefe'),
#    Hashtag(Text=u'Cuba')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724768),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 62,
#   'text': u'RT @peddoc63: Trump is in #LittleHavana to announce a #BetterDealForCuba and then they can celebrate with some Cuban #Covfefe \u2615\ufe0f#MAGA #Cuba\u2026',
#   'tweet_id': 875780842953605126,
#   'urls': [],
#   'user_followers_count': 20359,
#   'user_friends_count': 20220,
#   'user_handle': u'Prepper Silver',
#   'user_id': 1216957902,
#   'user_lang': u'en',
#   'user_location': u'Northwest Illinois',
#   'user_screen_name': u'PrepperSilver'},
#  {'created_at': u'Fri Jun 16 18:23:00 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'LittleHavana'),
#    Hashtag(Text=u'BetterDealForCuba'),
#    Hashtag(Text=u'Covfefe'),
#    Hashtag(Text=u'Cuba')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724772),
#   'posting_method': u'<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#   'retweet_count': 62,
#   'text': u'RT @peddoc63: Trump is in #LittleHavana to announce a #BetterDealForCuba and then they can celebrate with some Cuban #Covfefe \u2615\ufe0f#MAGA #Cuba\u2026',
#   'tweet_id': 875780764104769537,
#   'urls': [],
#   'user_followers_count': 2381,
#   'user_friends_count': 4221,
#   'user_handle': u'Trump Movement \U0001f1fa\U0001f1f8',
#   'user_id': 892531374,
#   'user_lang': u'en',
#   'user_location': u'Los Angeles, California ',
#   'user_screen_name': u'CA_4_Trump'},
#  {'created_at': u'Fri Jun 16 18:22:51 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'AmericaFirst'),
#    Hashtag(Text=u'covfefe'),
#    Hashtag(Text=u'trump')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724776),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 281,
#   'text': u"RT @WayneDupreeShow: #AmericaFirst - Obama's Anchor Baby Program (DAPA) Was Just Rescinded By Trump https://t.co/B8imehOAHw #covfefe #trump",
#   'tweet_id': 875780726800752640,
#   'urls': [URL(URL=https://t.co/B8imehOAHw, ExpandedURL=http://waynedupree.com/trump-rescinds-anchor-baby-program/)],
#   'user_followers_count': 439,
#   'user_friends_count': 528,
#   'user_handle': u'C Ranes',
#   'user_id': 48414468,
#   'user_lang': u'en',
#   'user_location': u'Williamsburg, VA',
#   'user_screen_name': u'cranes5'},
#  {'created_at': u'Fri Jun 16 18:22:47 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724782),
#   'posting_method': u'<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'retweet_count': 10,
#   'text': u'RT @bastiansorge: Wenn etwas in der @ARDde-Aussprachedatenbank steht, dann existiert es auch. #Covfefe https://t.co/ypfJbKiPt7',
#   'tweet_id': 875780710564593664,
#   'urls': [URL(URL=https://t.co/ypfJbKiPt7, ExpandedURL=https://twitter.com/sebmeyer/status/875645062280912896)],
#   'user_followers_count': 197,
#   'user_friends_count': 870,
#   'user_handle': u'Thomas Bache',
#   'user_id': 776746670,
#   'user_lang': u'de',
#   'user_location': u'Kiel, Germany',
#   'user_screen_name': u'tomingerson'},
#  {'created_at': u'Fri Jun 16 18:22:26 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 14, 724786),
#   'posting_method': u'<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for i\u039fS</a>',
#   'retweet_count': 10,
#   'text': u'RT @bastiansorge: Wenn etwas in der @ARDde-Aussprachedatenbank steht, dann existiert es auch. #Covfefe https://t.co/ypfJbKiPt7',
#   'tweet_id': 875780621871788033,
#   'urls': [URL(URL=https://t.co/ypfJbKiPt7, ExpandedURL=https://twitter.com/sebmeyer/status/875645062280912896)],
#   'user_followers_count': 857,
#   'user_friends_count': 2151,
#   'user_handle': u'Leonard Wolf',
#   'user_id': 576317418,
#   'user_lang': u'de',
#   'user_location': u'Berlin / Hennigsdorf',
#   'user_screen_name': u'woLeonard'},
#  {'created_at': u'Fri Jun 16 18:22:12 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 15, 269287),
#   'posting_method': u'<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'retweet_count': 10,
#   'text': u'RT @bastiansorge: Wenn etwas in der @ARDde-Aussprachedatenbank steht, dann existiert es auch. #Covfefe https://t.co/ypfJbKiPt7',
#   'tweet_id': 875780562857996288,
#   'urls': [URL(URL=https://t.co/ypfJbKiPt7, ExpandedURL=https://twitter.com/sebmeyer/status/875645062280912896)],
#   'user_followers_count': 669,
#   'user_friends_count': 395,
#   'user_handle': u'purrrlegon',
#   'user_id': 107502279,
#   'user_lang': u'de',
#   'user_location': u'rheinische Riviera',
#   'user_screen_name': u'pulegon'},
#  {'created_at': u'Fri Jun 16 18:22:09 +0000 2017',
#   'favorite_count': 2,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 15, 269323),
#   'posting_method': u'<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'retweet_count': 1,
#   'text': u'yasss. Kenyans always ftw #Covfefe https://t.co/5h2u23O4jD',
#   'tweet_id': 875780551659016192,
#   'urls': [URL(URL=https://t.co/5h2u23O4jD, ExpandedURL=https://twitter.com/gchelwa/status/874178656913981440)],
#   'user_followers_count': 953,
#   'user_friends_count': 359,
#   'user_handle': u'Zoe Marks',
#   'user_id': 226211256,
#   'user_lang': u'en',
#   'user_location': u'SEA OXF FNA CDG LHR EDI BOS',
#   'user_screen_name': u'z_marks'},
#  {'created_at': u'Fri Jun 16 18:22:02 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe'),
#    Hashtag(Text=u'Trump'),
#    Hashtag(Text=u'MAGA')],
#   'media': [Media(ID=875780520898170880, Type=photo, DisplayURL='pic.twitter.com/sErPZTwSrr')],
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 15, 269329),
#   'posting_method': u'<a href="http://www.automatedstench.com" rel="nofollow">Speaker Ryan ACA</a>',
#   'retweet_count': 0,
#   'text': u'Hello @SpeakerRyan have you cancelled Obamacare today?  #Covfefe #Trump #MAGA https://t.co/sErPZTwSrr',
#   'tweet_id': 875780523322462208,
#   'urls': [],
#   'user_followers_count': 54,
#   'user_friends_count': 2,
#   'user_handle': u'Speaker Ryan ACA',
#   'user_id': 822561591367528450,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'Ryan_ACA'},
#  {'created_at': u'Fri Jun 16 18:21:48 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 15, 269334),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 10,
#   'text': u'RT @bastiansorge: Wenn etwas in der @ARDde-Aussprachedatenbank steht, dann existiert es auch. #Covfefe https://t.co/ypfJbKiPt7',
#   'tweet_id': 875780462429577216,
#   'urls': [URL(URL=https://t.co/ypfJbKiPt7, ExpandedURL=https://twitter.com/sebmeyer/status/875645062280912896)],
#   'user_followers_count': 558,
#   'user_friends_count': 293,
#   'user_handle': u'Stefan Eilts',
#   'user_id': 482238618,
#   'user_lang': u'de',
#   'user_location': u'Hamburg und Kiel',
#   'user_screen_name': u'SteEilts'},
#  {'created_at': u'Fri Jun 16 18:21:02 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'SpicerFacts'),
#    Hashtag(Text=u'MAGA'),
#    Hashtag(Text=u'Covfefe')],
#   'media': [Media(ID=875780269642579968, Type=photo, DisplayURL='pic.twitter.com/aYr8tsK48r')],
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 15, 269339),
#   'posting_method': u'<a href="http://www.automatedstench.com" rel="nofollow">SpicerBot</a>',
#   'retweet_count': 0,
#   'text': u'Oi @SeanSpicer your reported timeline for the Gen. Flynn debacle does not add up #SpicerFacts #MAGA #Covfefe https://t.co/aYr8tsK48r',
#   'tweet_id': 875780272498892804,
#   'urls': [],
#   'user_followers_count': 72,
#   'user_friends_count': 2,
#   'user_handle': u'Sean Spicer Truths',
#   'user_id': 823628103830425602,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'SeanSp1cer'},
#  {'created_at': u'Fri Jun 16 18:20:28 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Covfefe')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 15, 269344),
#   'posting_method': u'<a href="https://mobile.twitter.com" rel="nofollow">Twitter Lite</a>',
#   'retweet_count': 0,
#   'text': u'@firkiii @thephukdi Javed Akthar ~ #Covfefe \u0915\u0930\u0928\u0947 \u0935\u093e\u0932\u0947 \u0915\u0940 \u0939\u093e\u0930 \u0928\u0939\u0940 \u0939\u094b\u0924\u0940',
#   'tweet_id': 875780129472913408,
#   'urls': [],
#   'user_followers_count': 470,
#   'user_friends_count': 454,
#   'user_handle': u'Yogi DonaldNath',
#   'user_id': 2430197594,
#   'user_lang': u'en',
#   'user_location': u'',
#   'user_screen_name': u'SuitBootkaTweet'},
#  {'created_at': u'Fri Jun 16 18:20:15 +0000 2017',
#   'favorite_count': 0,
#   'hashtags': [Hashtag(Text=u'Periscope'),
#    Hashtag(Text=u'Covfefe'),
#    Hashtag(Text=u'ExposeTheLeft'),
#    Hashtag(Text=u'trolls'),
#    Hashtag(Text=u'Scalise'),
#    Hashtag(Text=u'MAGA'),
#    Hashtag(Text=u'CCOT')],
#   'media': None,
#   'mined_at': datetime.datetime(2017, 6, 17, 22, 45, 15, 269350),
#   'posting_method': u'<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'retweet_count': 1,
#   'text': u'RT @kentuckipatriot: .@SusanKnowles on #Periscope: Happy #Covfefe Friday! Now come on in &amp; #ExposeTheLeft No #trolls #Scalise #MAGA #CCOT h\u2026',
#   'tweet_id': 875780074175209472,
#   'urls': [],
#   'user_followers_count': 10725,
#   'user_friends_count': 11339,
#   'user_handle': u'SusanKnowles',
#   'user_id': 18466375,
#   'user_lang': u'en',
#   'user_location': u'USA',
#   'user_screen_name': u'SusanKnowles'},
#  ...]

# %%
# Also saving to .json since the encoding for to_csv has been causing some problems with creating extra rows when I
# read in the .csv version
df.to_json('covfefe_hashtag_tweets_json.json')

# %%
col_names = df.columns
col_names
# Out:
# Index([u'created_at', u'favorite_count', u'hashtags', u'media', u'mined_at',
#        u'posting_method', u'retweet_count', u'text', u'tweet_id', u'urls',
#        u'user_followers_count', u'user_friends_count', u'user_handle',
#        u'user_id', u'user_lang', u'user_location', u'user_screen_name'],
#       dtype='object')

# %%
df.head()
# Out:
#                        created_at  favorite_count  \
# 0  Fri Jun 16 13:13:32 +0000 2017            1336
# 1  Fri Jun 16 16:53:35 +0000 2017             389
# 2  Fri Jun 16 16:25:06 +0000 2017             497
# 3  Fri Jun 16 23:59:46 +0000 2017               0
# 4  Fri Jun 16 23:59:17 +0000 2017               0
#
#                                             hashtags  \
# 0  [{"text": "trump"}, {"text": "maga"}, {"text":...
# 1           [{"text": "covfefe"}, {"text": "trump"}]
# 2  [{"text": "AmericaFirst"}, {"text": "covfefe"}...
# 3  [{"text": "AmericaFirst"}, {"text": "covfefe"}...
# 4  [{"text": "CNNisISIS"}, {"text": "AlBaghdadi"}...
#
#                                                media  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  [{"display_url": "pic.twitter.com/U5Wg4g1Ird",...
#
#                     mined_at  \
# 0 2017-06-17 22:45:08.039302
# 1 2017-06-17 22:45:08.039313
# 2 2017-06-17 22:45:08.039318
# 3 2017-06-17 22:45:08.039322
# 4 2017-06-17 22:45:08.039326
#
#                                       posting_method  retweet_count  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...            899
# 1  <a href="http://twitter.com" rel="nofollow">Tw...            271
# 2  <a href="http://twitter.com" rel="nofollow">Tw...            281
# 3  <a href="http://twitter.com/download/iphone" r...            281
# 4  <a href="http://twitter.com/download/iphone" r...              4
#
#                                                 text            tweet_id  \
# 0  AMERICA AGREES! Gohmert: There Is No Collusion...  875702885572595712
# 1  JUST FIRE MUELLER! Deputy AG Just Dropped Warn...  875758262959960068
# 2  #AmericaFirst - Obama's Anchor Baby Program (D...  875751095414521858
# 3  RT @WayneDupreeShow: #AmericaFirst - Obama's A...  875865514626646016
# 4  RT @politstrip: 'Caliphate News Network' mourn...  875865396045389825
#
#                                                 urls  user_followers_count  \
# 0  [{"expanded_url": "http://waynedupree.com/gohm...                192275
# 1  [{"expanded_url": "http://waynedupree.com/depu...                192275
# 2  [{"expanded_url": "http://waynedupree.com/trum...                192275
# 3  [{"expanded_url": "http://waynedupree.com/trum...                  3268
# 4                                                 []                   110
#
#    user_friends_count       user_handle     user_id user_lang  \
# 0                9517    🎙Wayne Dupree   282695161        en
# 1                9517    🎙Wayne Dupree   282695161        en
# 2                9517    🎙Wayne Dupree   282695161        en
# 3                4999      Crystal kemp  2481854702        en
# 4                  85  Elizabeth Wright  3707893403        en
#
#                   user_location user_screen_name
# 0  USAF Desert Storm/Shield Vet  WayneDupreeShow
# 1  USAF Desert Storm/Shield Vet  WayneDupreeShow
# 2  USAF Desert Storm/Shield Vet  WayneDupreeShow
# 3             Pennsylvania, USA     ckemp1542400
# 4                                 ErwrightWright

# %%
df.tail()
# Out:
#                            created_at  favorite_count  \
# 59340  Thu Jun 08 16:31:03 +0000 2017               0
# 59341  Thu Jun 08 16:30:18 +0000 2017               0
# 59342  Thu Jun 08 16:29:07 +0000 2017               0
# 59343  Thu Jun 08 16:27:44 +0000 2017               0
# 59344  Thu Jun 08 16:22:10 +0000 2017               0
#
#                                                 hashtags media  \
# 59340                              [{"text": "covfefe"}]  None
# 59341  [{"text": "ComeyDay"}, {"text": "Covfefe"}, {"...  None
# 59342        [{"text": "Covfefe"}, {"text": "ComeyDay"}]  None
# 59343  [{"text": "Leakers"}, {"text": "Loser"}, {"tex...  None
# 59344  [{"text": "trustthisguy"}, {"text": "covfefe"}...  None
#
#                         mined_at  \
# 59340 2017-06-17 23:45:37.287394
# 59341 2017-06-17 23:45:37.287399
# 59342 2017-06-17 23:45:37.287404
# 59343 2017-06-17 23:45:37.287408
# 59344 2017-06-17 23:45:37.287413
#
#                                           posting_method  retweet_count  \
# 59340  <a href="http://www.hootsuite.com" rel="nofoll...              0
# 59341  <a href="http://twitter.com" rel="nofollow">Tw...              0
# 59342  <a href="http://twitter.com/#!/download/ipad" ...              0
# 59343  <a href="http://twitter.com" rel="nofollow">Tw...              0
# 59344  <a href="http://twitter.com/download/android" ...              0
#
#                                                     text            tweet_id  \
# 59340  Comey: "I'm not gonna sit here and try to inte...  872853491018072064
# 59341  @KellyannePolls @POTUS #ComeyDay   You are stu...  872853302492397568
# 59342  If the #Covfefe shits wear it. #ComeyDay https...  872853003442819073
# 59343  #Leakers #Loser #MAGA #Covfefe #ComeyDay https...  872852656787771392
# 59344  @AskLyft I trust your statement as much as I #...  872851254019579906
#
#                                                     urls  \
# 59340                                                 []
# 59341                                                 []
# 59342  [{"expanded_url": "https://twitter.com/ac360/s...
# 59343  [{"expanded_url": "https://twitter.com/sassyca...
# 59344  [{"expanded_url": "https://twitter.com/i/web/s...
#
#        user_followers_count  user_friends_count         user_handle  \
# 59340                   653                1643       Melissa Green
# 59341                   437                 612   Ruthann L. Chapin
# 59342                   526                 546  corliss jean cogan
# 59343                  5360                5197         🇺🇸 ggg217
# 59344                     1                   2       Jesu Berkeley
#
#                   user_id user_lang                user_location  \
# 59340            14062950        en                  Oakland, CA
# 59341  700981141390671872        en                    Ohio, USA
# 59342          1053485478        en  The banks of Medicine Creek
# 59343           579254908        en                 Pennsylvania
# 59344  870563485536616448        en
#
#       user_screen_name
# 59340       ProfCritic
# 59341  RetroVintage4Me
# 59342     dogmomdogma1
# 59343           ggg217
# 59344     yourmamanfav
